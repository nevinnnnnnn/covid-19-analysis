# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display plots inline
# %matplotlib inline

# %%
covid_df = pd.read_csv("covid19_Confirmed_dataset.csv")
covid_df.drop(["Lat", "Long", "Province/State"], axis=1, inplace=True)

# %%
covid_grouped = covid_df.groupby("Country/Region").sum()

# %%
print("Shape:", covid_grouped.shape)
covid_grouped.head()
# Out:
# Shape: (187, 100)
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
countries = ['India', 'US', 'Italy', 'Spain', 'China']
for country in countries:
    covid_grouped.loc[country].plot(label=country)

# %%
plt.legend()
plt.title("COVID-19 Confirmed Cases Over Time")
plt.xlabel("Date")
plt.ylabel("Confirmed Cases")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
total_cases = covid_grouped.iloc[:, -1]  # latest available data
total_cases.sort_values(ascending=False).head(10).plot(kind='bar')
plt.title("Top 10 Countries with Most Confirmed Cases")
plt.xlabel("Country")
plt.ylabel("Total Cases")
plt.show()

# %%
covid_daily = covid_grouped.diff(axis=1)
covid_daily.fillna(0, inplace=True)

for country in countries:
    covid_daily.loc[country].plot(label=country)

# %%
plt.legend()
plt.title("Daily New COVID-19 Cases")
plt.xlabel("Date")
plt.ylabel("New Cases")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
max_infection_rates = covid_daily.max(axis=1)
covid_max_df = pd.DataFrame(max_infection_rates)
covid_max_df.columns = ['Max Infection Rate']
covid_max_df.head()
# Out:
#                 Max Infection Rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %%
happiness_df = pd.read_csv("worldwide_happiness_report.csv")

# %%
happiness_df.rename(columns={"Country or region": "Country"}, inplace=True)

# %%
happiness_df.set_index("Country", inplace=True)
combined_df = covid_max_df.join(happiness_df, how="inner")

# %%
correlation = combined_df.corr()
print("Correlation Matrix:")
print(correlation)
# Out:
# Correlation Matrix:
#                               Max Infection Rate  Overall rank     Score  \
# Max Infection Rate                      1.000000     -0.244777  0.228783
# Overall rank                           -0.244777      1.000000 -0.988972
# Score                                   0.228783     -0.988972  1.000000
# GDP per capita                          0.250118     -0.802204  0.793847
# Social support                          0.191958     -0.780955  0.788591
# Healthy life expectancy                 0.289263     -0.804753  0.799893
# Freedom to make life choices            0.078196     -0.570490  0.587007
# Generosity                             -0.114635     -0.063107  0.090420
# Perceptions of corruption               0.097703     -0.389360  0.420437
#
#                               GDP per capita  Social support  \
# Max Infection Rate                  0.250118        0.191958
# Overall rank                       -0.802204       -0.780955
# ...

# %%
numeric_df = merged_df.select_dtypes(include=[np.number])

# %%
# Create correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap: COVID-19 vs Happiness Indicators")
plt.show()

# %%
# Infection Rate vs GDP
sns.scatterplot(x="GDP per capita", y="Max Infection Rate", data=combined_df)
plt.title("GDP vs Max Infection Rate")
plt.show()

# %%
# Happiness vs Total Cases
sns.scatterplot(data=merged_df, x='Happiness Score', y='Total Cases')
plt.title("Happiness Score vs COVID-19 Total Cases")
plt.show()

# %%
sns.regplot(x="GDP per capita", y="Max Infection Rate", data=combined_df)
plt.title("Regression: GDP vs Max Infection Rate")
plt.show()

# %%
# Infection Rate vs Life Expectancy
sns.scatterplot(x="Healthy life expectancy", y="Max Infection Rate", data=combined_df)
plt.title("Life Expectancy vs Max Infection Rate")
plt.show()

# %%
sns.regplot(x="Healthy life expectancy", y="Max Infection Rate", data=combined_df)
plt.title("Regression: Life Expectancy vs Max Infection Rate")
plt.show()
